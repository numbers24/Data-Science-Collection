# %%
#problem 3
import pandas as pd
df = pd.read_csv(r'Credit_test.csv')

Ydefault = list(df.groupby(by='DEFAULT').size())[1]
Ndefault = list(df.groupby(by='DEFAULT').size())[0]
totalDefault = Ydefault+Ndefault
prob = Ydefault/totalDefault
print(prob)

#problem 4
prob = Ndefault/totalDefault
print(prob)

#problem 5
bustype = (df.groupby(by="BUSTYPE").size())
print(bustype.idxmax())

#problem 6
print(min(bustype.idxmin()))
# Out:
# 0.06914592760180996
# 0.9308540723981901
# A
# E

# %%
#problem 9
df.boxplot(column = 'MAXLINEUTIL')
# Out:
# <AxesSubplot:>

# %%
#10
df.hist(column = 'TOTACBAL')
# Out:
# array([[<AxesSubplot:title={'center':'TOTACBAL'}>]], dtype=object)

# %%
#problem 11
df.boxplot(column = 'BUSAGE')
# Out:
# <AxesSubplot:>

# %%
#12
df.hist(column = 'DAYSDELQ')
# Out:
# array([[<AxesSubplot:title={'center':'DAYSDELQ'}>]], dtype=object)
